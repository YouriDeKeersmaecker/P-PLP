# %%
import importlib
import p_plp.db
from sqlalchemy import text
from p_plp.db import get_engine
import p_plp.db.utils
from p_plp.db import read_table
importlib.reload(p_plp.db.utils)
dir(p_plp.db.utils)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'get_engine',
#  'pd',
#  'read_table',
#  'text']

# %%
engine = get_engine()

with engine.connect() as conn:
    print(conn.execute(text("select current_database()")).scalar())
    
with engine.connect() as conn:
    schemas = conn.execute(text("""
        select schema_name
        from information_schema.schemata
        order by schema_name
    """)).fetchall()
schemas
# Out:
# syntheasmall
# [('information_schema',),
#  ('native',),
#  ('pg_catalog',),
#  ('pg_temp_6',),
#  ('pg_toast',),
#  ('pg_toast_temp_6',),
#  ('public',),
#  ('syntheasmall',)]

# %%
df = read_table("person", "syntheasmall", limit=100)
df.head()
# Out:
#    person_id  gender_concept_id  year_of_birth  month_of_birth  day_of_birth  \
# 0          1               8532           1977               6            30
# 1          2               8507           1981               9            18
# 2          3               8507           1967               5            14
# 3          4               8507           1987               1             9
# 4          5               8532           2009               6            27
#
#   birth_datetime  race_concept_id  ethnicity_concept_id  location_id  \
# 0     1977-06-30             8527              38003564           74
# 1     1981-09-18             8515              38003563           10
# 2     1967-05-14             8515              38003564           79
# 3     1987-01-09             8527              38003564           73
# 4     2009-06-27                0              38003564           35
#
#   provider_id care_site_id                   person_source_value  \
# ...
