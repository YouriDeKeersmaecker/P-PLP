# %%
import importlib
import p_plp.db
from sqlalchemy import text
from p_plp.db import get_engine
import p_plp.db.utils
from p_plp.db.utils import get_cdm_table, CdmTable, list_cdm_tables, list_conditions
importlib.reload(p_plp.db.utils)
dir(p_plp.db.utils)
# Out:
# ['CDM_SCHEMA',
#  'CdmTable',
#  'Enum',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'fetch_df',
#  'get_cdm_table',
#  'list_cdm_tables',
#  'list_conditions',
#  'pd',
#  'run_sql',
#  'text']

# %%
engine = get_engine()

list_cdm_tables(engine)
# Out:
#                       table_name
# 0                     all_visits
# 1           assign_all_visit_ids
# 2                      care_site
# 3                     cdm_source
# 4                         cohort
# 5              cohort_definition
# 6                        concept
# 7               concept_ancestor
# 8                  concept_class
# 9           concept_relationship
# 10               concept_synonym
# 11                 condition_era
# 12          condition_occurrence
# 13                          cost
# 14                         death
# 15               device_exposure
# 16                        domain
# 17                      dose_era
# 18                      drug_era
# 19                 drug_exposure
# 20                 drug_strength
# 21                       episode
# 22                 episode_event
# 23             fact_relationship
# 24               final_visit_ids
# 25                      location
# 26                   measurement
# ...

# %%
df_person = get_cdm_table(engine, CdmTable.DRUG_EXPOSURE)
df_person.head()
# Out:
#    drug_exposure_id  person_id  drug_concept_id drug_exposure_start_date  \
# 0                 1          1          1710617               2005-09-22
# 1                 2          1         19122186               2005-09-22
# 2                 3          1         19122186               2008-10-09
# 3                 4          1          1703093               2008-10-09
# 4                 5          1         40224805               1998-07-30
#
#   drug_exposure_start_datetime drug_exposure_end_date  \
# 0                   2005-09-22             2006-01-29
# 1                   2005-09-22             2006-01-29
# 2                   2008-10-09             2008-10-09
# 3                   2008-10-09             2008-10-09
# 4                   1998-07-30             1999-07-25
#
#   drug_exposure_end_datetime verbatim_end_date  drug_type_concept_id  \
# 0                 2006-01-29        2006-01-29                 32838
# ...

# %%
list_conditions(engine)
# Out:
#     concept_id                                       concept_name  \
# 0     35223476                          -W77 deactivated. See T71
# 1     35223478                  -W80 deactivated. See T17 and T18
# 2     35223764                          -X29 deactivated. See T63
# 3     35223831  -X69 deactivated. See categories T36-T65 with ...
# 4     35223963  -X90 deactivated. See categories T36-T65 with ...
# 5     35224123  -Y19 deactivated. See codes T36-T65 with sixth...
# 6     44823425  "Light-for-dates" with signs of fetal malnutri...
# 7     44825777  "Light-for-dates" with signs of fetal malnutri...
# 8     44825778  "Light-for-dates" with signs of fetal malnutri...
# 9     44836268  "Light-for-dates" with signs of fetal malnutri...
# 10    44833901  "Light-for-dates" with signs of fetal malnutri...
# 11    44821220  "Light-for-dates" with signs of fetal malnutri...
# 12    44822273  "Light-for-dates" with signs of fetal malnutri...
# ...
