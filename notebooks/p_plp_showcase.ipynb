# %% [markdown]
# # P-PLP showcase
#
# This notebook starts with the two basics: connecting to the database and loading a cohort with `p_plp`.

# %% [markdown]
# ## 1. Connect to the database
#
# Set the connection details for the datasource you want to use, then create a configured SQLAlchemy engine. `get_engine(...)` now validates the connection and configured schemas automatically.

# %%
from p_plp.db import *
DATABASE_URL = "postgresql+psycopg2://postgres:password@localhost:5432/synpuf100kaws"
CDM_SCHEMA = "public"
VOCABULARY_SCHEMA = "public"
WORK_SCHEMA = "plp_work"

engine = get_engine(
    source_name="postgres",
    database_url=DATABASE_URL,
    cdm_schema=CDM_SCHEMA,
    vocabulary_schema=VOCABULARY_SCHEMA,
    work_schema=WORK_SCHEMA,
)

source_config = get_engine_config(engine)
print(f"Connected to: {source_config.database_url}")
print(f"CDM schema: {source_config.cdm_schema}")
print(f"Vocabulary schema: {source_config.vocabulary_schema}")
print(f"Work schema: {source_config.work_schema}")
# Out:
# Connected to: postgresql+psycopg2://postgres:Formule1.@localhost:5432/synpuf100kaws
# CDM schema: public
# Vocabulary schema: public
# Work schema: plp_work

# %%
list_cdm_tables(engine).head()
# Out:
#              table_name
# 0  attribute_definition
# 1             care_site
# 2            cdm_source
# 3                cohort
# 4      cohort_attribute

# %%
read_table(engine, "person")
# Out:
#     person_id  gender_concept_id  year_of_birth  month_of_birth  day_of_birth  \
# 0          34               8532           1919              10             1
# 1          41               8507           1932               2             1
# 2          83               8532           1963               5             1
# 3         103               8507           1919               4             1
# 4         178               8507           1928               6             1
# 5         197               8507           1929              12             1
# 6         218               8532           1912               6             1
# 7         237               8507           1949              12             1
# 8         300               8507           1953               1             1
# 9         307               8507           1959               2             1
# 10        350               8507           1942               9             1
# 11        352               8532           1938               8             1
# 12        369               8507           1932               3             1
# 13        387               8532           1938               7             1
# 14        430               8532           1941               4             1
# 15        441               8532           1930               9             1
# 16        491               8507           1916               8             1
# 17        517               8507           1924               2             1
# 18        561               8507           1936               3             1
# 19        608               8507           1934               4             1
#
#    birth_datetime  race_concept_id  ethnicity_concept_id  location_id  \
# 0            None             8527              38003564           34
# 1            None             8527              38003564           41
# 2            None             8527              38003564           77
# 3            None             8527              38003564           93
# 4            None             8527              38003564          145
# 5            None             8527              38003564          156
# 6            None             8527              38003564          160
# 7            None             8527              38003564          181
# 8            None             8527              38003564          221
# 9            None                0              38003564          225
# 10           None             8527              38003564           69
# 11           None             8527              38003564           65
# 12           None             8527              38003564          261
# 13           None             8527              38003564           63
# 14           None             8516              38003564          298
# 15           None             8527              38003564          306
# 16           None             8527              38003564           23
# 17           None             8527              38003564          348
# 18           None                0              38003564          243
# 19           None             8516              38003564          396
#
#    provider_id care_site_id person_source_value gender_source_value  \
# 0         None         None    00151A878F9A2C0D                   2
# 1         None         None    0018BD6F2F493452                   1
# 2         None         None    002578091E1953AF                   2
# 3         None         None    002F1C637DB118F8                   1
# 4         None         None    0058B2A556D74DC2                   1
# 5         None         None    00647033295B9409                   1
# 6         None         None    00701D6A8CED0F34                   2
# 7         None         None    007C99D466D0E3A6                   1
# 8         None         None    009F3B312590919F                   1
# 9         None         None    00A1356477809B39                   1
# 10        None         None    00B7FD9325DDC843                   1
# 11        None         None    00B80FECBF09CE21                   2
# 12        None         None    00BE58ECD4233009                   1
# 13        None         None    00C99F205C1B69DF                   2
# 14        None         None    00DE30DD704591A5                   2
# 15        None         None    00E2EF80EEFD73DB                   2
# 16        None         None    00FDFA655DD462F8                   1
# 17        None         None    010834A901DCFC05                   1
# 18        None         None    01238F5F6E673360                   1
# 19        None         None    013809D6C12B788D                   1
#
#    gender_source_concept_id race_source_value race_source_concept_id  \
# 0                      None                 1                   None
# 1                      None                 1                   None
# 2                      None                 1                   None
# 3                      None                 1                   None
# 4                      None                 1                   None
# 5                      None                 1                   None
# 6                      None                 1                   None
# 7                      None                 1                   None
# 8                      None                 1                   None
# 9                      None                 3                   None
# 10                     None                 1                   None
# 11                     None                 1                   None
# 12                     None                 1                   None
# 13                     None                 1                   None
# 14                     None                 2                   None
# 15                     None                 1                   None
# 16                     None                 1                   None
# 17                     None                 1                   None
# 18                     None                 3                   None
# 19                     None                 2                   None
#
#    ethnicity_source_value ethnicity_source_concept_id
# 0                       1                        None
# 1                       1                        None
# 2                       1                        None
# 3                       1                        None
# 4                       1                        None
# 5                       1                        None
# 6                       1                        None
# 7                       1                        None
# 8                       1                        None
# 9                       3                        None
# 10                      1                        None
# 11                      1                        None
# 12                      1                        None
# 13                      1                        None
# 14                      2                        None
# 15                      1                        None
# 16                      1                        None
# 17                      1                        None
# 18                      3                        None
# 19                      2                        None
